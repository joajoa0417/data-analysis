# %%
a = [1, 3, 6, 4, 2, 5]
# a.sort()

# %%
sorted(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a
# Out:
# [1, 3, 6, 4, 2, 5]

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# 타이타닉 데이터셋 불러오기
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ages = [30, 40, 50, 60, 70, 80, 90]
backup_ages = ages[:]
ages.append(100)

# %%
print(ages)
print(backup_ages)
# Out:
# [30, 40, 50, 60, 70, 80, 90, 100]
# [30, 40, 50, 60, 70, 80, 90]

# %%
backup_df = df.copy()

# %%
df.drop(columns=['Embarked', 'Cabin', 'Ticket'], inplace=True)

# %%
backup_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
backup_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 결측치 수와 비율 계산
missing_values = df.isna().sum()  # 결측치 수
missing_ratio = (df.isna().sum() / len(df)) * 100  # 결측치 비율

# 결과를 데이터프레임으로 만들어서 출력
missing_df = pd.DataFrame({
    '결측치 수': missing_values,
    '결측치 비율(%)': missing_ratio
})
print('\n결측치 수와 비율:')
missing_df
# Out:
# 결측치 수와 비율:
#              결측치 수  결측치 비율(%)
# PassengerId      0    0.00000
# Survived         0    0.00000
# Pclass           0    0.00000
# Name             0    0.00000
# Sex              0    0.00000
# Age            177   19.86532
# SibSp            0    0.00000
# Parch            0    0.00000
# Fare             0    0.00000

# %%
name = 'chioh'
print(f"my name is {name}")
# Out:
# my name is chioh

# %%
# na_sum = df.isna().sum()# > a
# na_cols = na_sum[na_sum > 1]
# na_cols.index
# Out:
# Index(['Age'], dtype='object')

# %%
df.drop(columns=na_cols.index, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 55.8+ KB

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# SibSp          0
# Parch          0
# Fare           0
# dtype: int64

# %% [markdown]
# ## 결측치 대응
# ---
#
# 결측치가 존재하는 Age, Cabin, Embarked에 대해 대응

# %% [markdown]
# ### 결측치대응 1: Age

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Age.mean()
# Out:
# np.float64(29.69911764705882)

# %%
df["Age"] = df.Age.fillna(df.Age.mean())

# %%
df.Age.isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 결측치대응 2: Cabin

# %%
df.Cabin.isna().sum()
# Out:
# np.int64(687)

# %%
df = df.drop("Cabin", axis=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### 결측치대응3: Embarked

# %%
df = df[~df.Embarked.isna()]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 통계치 확인
# ----

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Embarked
# 0      0  A/5 21171   7.2500        S
# 1      0   PC 17599  71.2833        C

# %%
pd.set_option('mode.chained_assignment', None)

# %%
df["Sex"] = df.Sex.map({"male": 1, "female": 0})

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
#
#       Ticket     Fare Embarked
# 0  A/5 21171   7.2500        S
# 1   PC 17599  71.2833        C

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   889.000000  889.000000  889.000000  889.000000  889.000000
# mean    446.000000    0.382452    2.311586    0.649044   29.653446
# std     256.998173    0.486260    0.834700    0.477538   12.968366
# min       1.000000    0.000000    1.000000    0.000000    0.420000
# 25%     224.000000    0.000000    2.000000    0.000000   22.000000
# 50%     446.000000    0.000000    3.000000    1.000000   29.699118
# 75%     668.000000    1.000000    3.000000    1.000000   35.000000
# max     891.000000    1.000000    3.000000    1.000000   80.000000
#
#             SibSp       Parch        Fare
# count  889.000000  889.000000  889.000000
# mean     0.524184    0.382452   32.096681
# std      1.103705    0.806761   49.697504
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.895800
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# ...

# %%
df.Ticket.value_counts()
# Out:
# Ticket
# 347082             7
# 1601               7
# CA. 2343           7
# CA 2144            6
# 347088             6
#                   ..
# SOTON/OQ 392076    1
# 211536             1
# 112053             1
# 111369             1
# 113788             1
# Name: count, Length: 680, dtype: int64

# %%
df.query("Ticket == '347082'")
# Out:
#      PassengerId  Survived  Pclass  \
# 13            14         0       3
# 119          120         0       3
# 541          542         0       3
# 542          543         0       3
# 610          611         0       3
# 813          814         0       3
# 850          851         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 13                         Andersson, Mr. Anders Johan    1  39.0      1
# 119                  Andersson, Miss. Ellis Anna Maria    0   2.0      4
# 541               Andersson, Miss. Ingeborg Constanzia    0   9.0      4
# 542                  Andersson, Miss. Sigrid Elisabeth    0  11.0      4
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...    0  39.0      1
# 813                 Andersson, Miss. Ebba Iris Alfrida    0   6.0      4
# 850            Andersson, Master. Sigvard Harald Elias    1   4.0      4
#
#      Parch  Ticket    Fare Embarked
# 13       5  347082  31.275        S
# ...

# %%
df_corr = df.corr(numeric_only=True)
df_corr
# Out:
#              PassengerId  Survived    Pclass       Sex     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000  0.131900  0.083081  0.018443
# Sex             0.042939 -0.543351  0.131900  1.000000 -0.114631 -0.245489
# SibSp          -0.057527 -0.035322  0.083081 -0.114631  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.245489  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Sex         -0.182333
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.select_dtypes(include=["number"])
# Out:
#      PassengerId  Survived  Pclass  Sex  SibSp  Parch     Fare
# 0              1         0       3    1      1      0   7.2500
# 1              2         1       1    0      1      0  71.2833
# 2              3         1       3    0      0      0   7.9250
# 3              4         1       1    0      1      0  53.1000
# 4              5         0       3    1      0      0   8.0500
# ..           ...       ...     ...  ...    ...    ...      ...
# 886          887         0       2    1      0      0  13.0000
# 887          888         1       1    0      0      0  30.0000
# 888          889         0       3    0      1      2  23.4500
# 889          890         1       1    1      0      0  30.0000
# 890          891         0       3    1      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.heatmap(df_corr, annot=True) # annot = 실제 값도 보여줌
# Out:
# <Axes: >

# %%
df_corr
# Out:
#              PassengerId  Survived    Pclass       Sex     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000  0.131900  0.083081  0.018443
# Sex             0.042939 -0.543351  0.131900  1.000000 -0.114631 -0.245489
# SibSp          -0.057527 -0.035322  0.083081 -0.114631  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.245489  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Sex         -0.182333
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df_corr.sort_values(by="Survived", key=abs, ascending=False).iloc[1:].head().Survived
# Out:
# Sex      -0.543351
# Pclass   -0.338481
# Fare      0.257307
# Parch     0.081629
# SibSp    -0.035322
# Name: Survived, dtype: float64

# %% [markdown]
# ### 상관계수 확인을 통한 인사이트 정리
# - 여성의 경우 생존의 확률이 남성에 비해 비교적으로 높음
# - 좋은 객실에 탑승한 경우 생존 확률이 높음
# - 나이가 정규분포에서 끝단일 경우 생존확률이 높을 것 같으나 이것은 상관계수로 직접적인 확인 불가하므로 시각화가 필요함

# %%
pip install matplotplib -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplotplib (from versions: none)
# ERROR: No matching distribution found for matplotplib

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Age_Group',y='Survived',hue='Pclass',errorbar=None)
plt.title('Survival Rate by Age Group')
plt.xlabel('Age Group')
plt.ylable('Survival Rate')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[211], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 sns.barplot(data=df, x='Age_Group',y='Survived',hue='Pclass',errorbar=None)
#       3 plt.title('Survival Rate by Age Group')
#       4 plt.xlabel('Age Group')
#
# File c:\conda\envs\python_basic\lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
# ...

# %%
df[df.Age==80.0]
# Out:
#      PassengerId  Survived  Pclass                                  Name  Sex  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson    1
#
#       Age  SibSp  Parch Ticket  Fare Embarked
# 630  80.0      0      0  27042  30.0        S

# %%
# 타이타닉 데이터셋 불러오기
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
df.to_csv("titanic.csv")

# %%
df["Title"] = df.Name.str.split(", ").str[1].str.split(".").str[0]

# %%
title_counts = df2.Title.value_counts()

# %%
# new_vc = vc[:4].copy()
# new_vc['Others'] = vc[4:].sum()

# new_vc
# Out:
# Title
# Mr        517
# Miss      182
# Mrs       125
# Master     40
# Others     27
# Name: count, dtype: int64

# %%
df.loc[~df.Title.isin(['Mr','Miss','Mrs','Master']),'Title'] = 'Others'
df.Title.value_counts()
# Out:
# Title
# Mr        517
# Miss      182
# Mrs       125
# Master     40
# Others     27
# Name: count, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def get_titanic_data(path="titanic.csv"):
    df = pd.read_csv(path)
    return df

def get_preprocessed_data(df):
    df.drop(columns=["Cabin"], inplace=True)
    df.dropna(subset=["Embarked"], inplace=True)
    df["Title"] = df.Name.str.split(", ").str[1].str.split(".").str[0]
    df.loc[~df.Title.isin(['Mr', 'Miss', 'Mrs', 'Master']), 'Title'] = 'Other'
    return df

df = get_titanic_data()
df = get_preprocessed_data(df)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[271], line 12
#       9     df.loc[~df.Title.isin(['Mr', 'Miss', 'Mrs', 'Master']), 'Title'] = 'Other'
#      10     return df
# ---> 12 df = get_titanic_data()
#      13 df = get_preprocessed_data(df)
#      14 df
#
# Cell In[271], line 2, in get_titanic_data(path)
#       1 def get_titanic_data(path="titanic.csv"):
# ----> 2     df = pd.read_csv(path)
#       3     return df
#
# ...

# %%
df2.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                                 Sex     Age     SibSp   Parch   Ticket    Fare     Cabin        Embarked  Title
# Others       Others    Others  Others                                               Others  Others  Others  Others  Others    Others   Others       Others    Others    27
# 4            1         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)         female  35.0    1       0       113803    53.1     C123         S         Mrs        1
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0    1       0       PC 17599  71.2833  C85          C         Mrs        1
# 11           1         3       Sandstrom, Miss. Marguerite Rut                      female  4.0     1       1       PP 9549   16.7     G6           S         Miss       1
# ...

# %%
df.Age.fillna(df.groupby(["Title","Sex","Survived","Pclass"]).Age.median()
# Out:
# Title   Sex     Survived  Pclass
# Master  male    0         3          5.400000
#                 1         1          5.306667
#                           2          2.258889
#                           3          5.268889
# Miss    female  0         1         26.000000
#                           2         31.000000
#                           3         17.810811
#                 1         1         30.186047
#                           2         21.816667
#                           3         14.171875
# Mr      male    0         1         44.045455
#                           2         32.460526
#                           3         28.895000
#                 1         1         37.343750
#                           2         36.666667
#                           3         27.551724
# Mrs     female  0         1         25.000000
#                           2         38.500000
#                           3         36.166667
#                 1         1         41.363636
# ...

# %%
df.groupby(["Sex"]).describe()
# Out:
#        PassengerId                                                             \
#              count        mean         std  min     25%    50%     75%    max
# Sex
# female       314.0  431.028662  256.846324  2.0  231.75  414.5  641.25  889.0
# male         577.0  454.147314  257.486139  1.0  222.00  464.0  680.00  891.0
#
#        Survived            ... Parch        Fare                              \
#           count      mean  ...   75%  max  count       mean        std   min
# Sex                        ...
# female    314.0  0.742038  ...   1.0  6.0  314.0  44.479818  57.997698  6.75
# male      577.0  0.188908  ...   0.0  5.0  577.0  25.523893  43.138263  0.00
#
#
#               25%   50%    75%       max
# Sex
# female  12.071875  23.0  55.00  512.3292
# male     7.895800  10.5  26.55  512.3292
#
# [2 rows x 56 columns]
